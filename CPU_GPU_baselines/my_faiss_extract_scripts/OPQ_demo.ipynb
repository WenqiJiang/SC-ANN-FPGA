# %%
# Reference: 
# OPQ demo: https://github.com/facebookresearch/faiss/issues/411
# Load preprocessing operator: https://github.com/facebookresearch/faiss/blob/master/benchs/bench_gpu_1bn.py

# %%
from __future__ import print_function
import os
import sys
import time
import numpy as np
import re
import faiss
import inspect
from multiprocessing.dummy import Pool as ThreadPool
from matplotlib import pyplot

# %%
# create an inverted index
nlist = 1024 # IVF cell number
m = 16 # PQ partitions
kbits = 8 # 2^5 = 32, 2^8 = 256
d = 128 # dim of db vectors
n = 100000 # num of db vectors

# %%
# fill it in
xb = faiss.rand((n, d), 1234)
# index.train(xb)
# index.add(xb)

# %%
# coarse_quantizer = faiss.IndexFlatL2(d)
# index = faiss.IndexIVFPQ(coarse_quantizer, d, nlist, m, kbits)

# %%
opq = faiss.OPQMatrix(d, m)
opq.train(xb)
xt = opq.apply_py(xb)
pq = faiss.ProductQuantizer(d, m, kbits)
pq.train(xt)
codes = pq.compute_codes(xb)

# %%
print("opq.A", opq.A)
print("opq.M", opq.M)
vec = faiss.vector_to_array(opq.A)
print(vec.shape) # 128 * 128
print(vec)
# Out:
# opq.A <faiss.swigfaiss_avx2.FloatVector; proxy of <Swig Object of type 'std::vector< float > *' at 0x7fd4b6dc34b0> >
# opq.M 16
# (16384,)
# [-0.09090281  0.09487255  0.09818375 ...  0.15406719 -0.08668799
#   0.02816606]

# %%
codes
# Out:
# array([[139,  11, 146, ..., 209, 149,  66],
#        [227,  11, 146, ..., 153, 247,  44],
#        [139,  11,  42, ...,  74, 149,  44],
#        ...,
#        [154,  11,  92, ...,  74,   8, 122],
#        [139,  11,  42, ...,  40, 247,  44],
#        [227,  11,  42, ...,  40, 149,  44]], dtype=uint8)

# %%
# Out:
# array([[-0.09090281,  0.09487255,  0.09818375, ..., -0.03984596,
#         -0.08296149, -0.00214473],
#        [ 0.08088752, -0.10553612, -0.03300218, ...,  0.05117955,
#         -0.13224462,  0.1514061 ],
#        [ 0.09209212,  0.10065087, -0.03060819, ..., -0.06132574,
#         -0.14832038, -0.18674988],
#        ...,
#        [ 0.00442195,  0.11818414, -0.00067089, ...,  0.01547248,
#         -0.04173023,  0.05076025],
#        [-0.09678233,  0.18215787,  0.06500293, ...,  0.00624335,
#          0.01511531,  0.11763625],
#        [-0.0023328 , -0.06425092,  0.07417437, ...,  0.15406719,
#         -0.08668799,  0.02816606]], dtype=float32)

# %%
OPQ_mat = np.reshape(vec, (128,128))
x_verify = np.matmul(xb, OPQ_mat)
print(x_verify)

OPQ_mat_T = np.transpose(OPQ_mat)
x_verify_T = np.matmul(xb, OPQ_mat_T)
print(x_verify_T)
# Out:
# [[ 0.33077395  0.80827886 -0.7675641  ... -0.03774748 -0.6464313
#    0.46730372]
#  [-0.2964133   0.38181987 -0.5297576  ...  0.1065072  -0.47322565
#    0.23144089]
#  [-0.4822103   0.94808215 -0.4776723  ...  0.46175957 -0.605573
#    0.4937843 ]
#  ...
#  [-0.19966108  0.25764626 -0.27646154 ...  0.22020607 -0.75905144
#    0.4758157 ]
#  [-0.32742465  0.21110094 -0.7843784  ...  0.02842903 -0.315985
#    0.15336634]
#  [-0.48186213  0.23942779  0.4081095  ...  0.61109334 -0.38750818
#    0.07828852]]
# [[ 0.66452736 -0.00846681 -0.56798387 ...  0.9972061   0.9702721
#    0.04158473]
#  [ 0.31273285 -0.13870661 -0.01504563 ...  0.2038115   1.565992
#    0.07616587]
#  [ 1.1000265  -0.16824633 -1.1169357  ...  0.98503643  1.737572
#    0.26097906]
#  ...
#  [ 0.7410809  -0.3422086  -0.2699805  ...  0.66872954  1.7959784
#    0.59956545]
#  [ 1.0574831  -0.29653358 -0.24074297 ...  1.1340361   1.2729566
#   -0.14015266]
#  [ 0.573179    0.3359762  -0.14394149 ...  1.0408187   1.7643989
#    0.2095789 ]]

# %%
print(xt, xt.shape)
# Out:
# [[ 0.66452736 -0.00846681 -0.56798387 ...  0.9972061   0.9702721
#    0.04158473]
#  [ 0.31273285 -0.13870661 -0.01504563 ...  0.2038115   1.565992
#    0.07616587]
#  [ 1.1000265  -0.16824633 -1.1169357  ...  0.98503643  1.737572
#    0.26097906]
#  ...
#  [ 0.7410809  -0.3422086  -0.2699805  ...  0.66872954  1.7959784
#    0.59956545]
#  [ 1.0574831  -0.29653358 -0.24074297 ...  1.1340361   1.2729566
#   -0.14015266]
#  [ 0.573179    0.3359762  -0.14394149 ...  1.0408187   1.7643989
#    0.2095789 ]] (100000, 128)

# %%
np.allclose(x_verify_T, xt)
# The transposed version of OPQ Matrix is used to preprocessing input vector
# Out:
# True

# %%
preproc = faiss.read_VectorTransform(
    "../trained_GPU_indexes/bench_gpu_SIFT100M_OPQ16,IVF16384,PQ16/preproc_SIFT100M_OPQ16.vectrans")
loaded_OPQ_mat = faiss.vector_to_array(preproc.A)
print(loaded_OPQ_mat, loaded_OPQ_mat.shape)
# Out:
# [ 0.04449736  0.14647843 -0.00979544 ...  0.07864936 -0.02518905
#  -0.11654815] (16384,)

# %%
inspect.getmembers(preproc)
# Out:
# [('A',
#   <faiss.swigfaiss_avx2.FloatVector; proxy of <Swig Object of type 'std::vector< float > *' at 0x7fd4b6c92d20> >),
#  ('__class__', faiss.swigfaiss_avx2.LinearTransform),
#  ('__del__',
#   <bound method LinearTransform.<lambda> of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('__delattr__',
#   <method-wrapper '__delattr__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__dict__',
#   {'this': <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00>}),
#  ('__dir__', <function LinearTransform.__dir__>),
#  ('__doc__', None),
#  ('__eq__',
#   <method-wrapper '__eq__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__format__', <function LinearTransform.__format__>),
#  ('__ge__',
#   <method-wrapper '__ge__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__getattr__',
#   <bound method LinearTransform.<lambda> of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('__getattribute__',
#   <method-wrapper '__getattribute__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__gt__',
#   <method-wrapper '__gt__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__hash__',
#   <method-wrapper '__hash__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__init__',
#   <bound method LinearTransform.__init__ of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('__init_subclass__', <function LinearTransform.__init_subclass__>),
#  ('__le__',
#   <method-wrapper '__le__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__lt__',
#   <method-wrapper '__lt__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__module__', 'faiss.swigfaiss_avx2'),
#  ('__ne__',
#   <method-wrapper '__ne__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__new__', <function object.__new__>),
#  ('__reduce__', <function LinearTransform.__reduce__>),
#  ('__reduce_ex__', <function LinearTransform.__reduce_ex__>),
#  ('__repr__',
#   <bound method _swig_repr of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('__setattr__',
#   <bound method LinearTransform.<lambda> of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('__sizeof__', <function LinearTransform.__sizeof__>),
#  ('__str__',
#   <method-wrapper '__str__' of LinearTransform object at 0x7fd4b6c598d0>),
#  ('__subclasshook__', <function LinearTransform.__subclasshook__>),
#  ('__swig_destroy__', <function faiss._swigfaiss_avx2.delete_LinearTransform>),
#  ('__swig_getmethods__',
#   {'d_in': <function faiss._swigfaiss_avx2.VectorTransform_d_in_get>,
#    'd_out': <function faiss._swigfaiss_avx2.VectorTransform_d_out_get>,
#    'is_trained': <function faiss._swigfaiss_avx2.VectorTransform_is_trained_get>,
#    'have_bias': <function faiss._swigfaiss_avx2.LinearTransform_have_bias_get>,
#    'is_orthonormal': <function faiss._swigfaiss_avx2.LinearTransform_is_orthonormal_get>,
#    'A': <function faiss._swigfaiss_avx2.LinearTransform_A_get>,
#    'b': <function faiss._swigfaiss_avx2.LinearTransform_b_get>,
#    'verbose': <function faiss._swigfaiss_avx2.LinearTransform_verbose_get>}),
#  ('__swig_setmethods__',
#   {'d_in': <function faiss._swigfaiss_avx2.VectorTransform_d_in_set>,
#    'd_out': <function faiss._swigfaiss_avx2.VectorTransform_d_out_set>,
#    'is_trained': <function faiss._swigfaiss_avx2.VectorTransform_is_trained_set>,
#    'have_bias': <function faiss._swigfaiss_avx2.LinearTransform_have_bias_set>,
#    'is_orthonormal': <function faiss._swigfaiss_avx2.LinearTransform_is_orthonormal_set>,
#    'A': <function faiss._swigfaiss_avx2.LinearTransform_A_set>,
#    'b': <function faiss._swigfaiss_avx2.LinearTransform_b_set>,
#    'verbose': <function faiss._swigfaiss_avx2.LinearTransform_verbose_set>}),
#  ('__weakref__', None),
#  ('_s', faiss.swigfaiss_avx2.VectorTransform),
#  ('apply',
#   <bound method VectorTransform.apply of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('apply_noalloc',
#   <bound method LinearTransform.apply_noalloc of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('apply_py',
#   <bound method handle_VectorTransform.<locals>.apply_method of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('b',
#   <faiss.swigfaiss_avx2.FloatVector; proxy of <Swig Object of type 'std::vector< float > *' at 0x7fd4b6c929f0> >),
#  ('d_in', 128),
#  ('d_out', 128),
#  ('have_bias', False),
#  ('is_orthonormal', True),
#  ('is_trained', True),
#  ('print_if_verbose',
#   <bound method LinearTransform.print_if_verbose of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('reverse_transform',
#   <bound method handle_VectorTransform.<locals>.replacement_reverse_transform of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('reverse_transform_c',
#   <bound method LinearTransform.reverse_transform of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('set_is_orthonormal',
#   <bound method LinearTransform.set_is_orthonormal of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('this', <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00>),
#  ('train',
#   <bound method handle_VectorTransform.<locals>.replacement_vt_train of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('train_c',
#   <bound method VectorTransform.train of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('transform_transpose',
#   <bound method LinearTransform.transform_transpose of <faiss.swigfaiss_avx2.LinearTransform; proxy of <Swig Object of type 'faiss::LinearTransform *' at 0x7fd4eb4a8f00> >>),
#  ('verbose', False)]

# %%
inspect.getmembers(faiss)
# Out:
# [('ArrayInvertedLists', faiss.swigfaiss_avx2.ArrayInvertedLists),
#  ('ArrayInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.ArrayInvertedLists_swigregister>),
#  ('AutoTuneCriterion', faiss.swigfaiss_avx2.AutoTuneCriterion),
#  ('AutoTuneCriterion_swigregister',
#   <function faiss._swigfaiss_avx2.AutoTuneCriterion_swigregister>),
#  ('BitstringReader', faiss.swigfaiss_avx2.BitstringReader),
#  ('BitstringReader_swigregister',
#   <function faiss._swigfaiss_avx2.BitstringReader_swigregister>),
#  ('BitstringWriter', faiss.swigfaiss_avx2.BitstringWriter),
#  ('BitstringWriter_swigregister',
#   <function faiss._swigfaiss_avx2.BitstringWriter_swigregister>),
#  ('BufferList', faiss.swigfaiss_avx2.BufferList),
#  ('BufferList_swigregister',
#   <function faiss._swigfaiss_avx2.BufferList_swigregister>),
#  ('BufferedIOReader', faiss.swigfaiss_avx2.BufferedIOReader),
#  ('BufferedIOReader_swigregister',
#   <function faiss._swigfaiss_avx2.BufferedIOReader_swigregister>),
#  ('BufferedIOWriter', faiss.swigfaiss_avx2.BufferedIOWriter),
#  ('BufferedIOWriter_swigregister',
#   <function faiss._swigfaiss_avx2.BufferedIOWriter_swigregister>),
#  ('ByteVector', faiss.swigfaiss_avx2.ByteVector),
#  ('ByteVectorVector', faiss.swigfaiss_avx2.ByteVectorVector),
#  ('ByteVectorVector_swigregister',
#   <function faiss._swigfaiss_avx2.ByteVectorVector_swigregister>),
#  ('ByteVector_swigregister',
#   <function faiss._swigfaiss_avx2.ByteVector_swigregister>),
#  ('CenteringTransform', faiss.swigfaiss_avx2.CenteringTransform),
#  ('CenteringTransform_swigregister',
#   <function faiss._swigfaiss_avx2.CenteringTransform_swigregister>),
#  ('CharVector', faiss.swigfaiss_avx2.CharVector),
#  ('CharVector_swigregister',
#   <function faiss._swigfaiss_avx2.CharVector_swigregister>),
#  ('Cloner', faiss.swigfaiss_avx2.Cloner),
#  ('Cloner_swigregister', <function faiss._swigfaiss_avx2.Cloner_swigregister>),
#  ('Clustering', faiss.swigfaiss_avx2.Clustering),
#  ('ClusteringIterationStats', faiss.swigfaiss_avx2.ClusteringIterationStats),
#  ('ClusteringIterationStatsVector',
#   faiss.swigfaiss_avx2.ClusteringIterationStatsVector),
#  ('ClusteringIterationStatsVector_swigregister',
#   <function faiss._swigfaiss_avx2.ClusteringIterationStatsVector_swigregister>),
#  ('ClusteringIterationStats_swigregister',
#   <function faiss._swigfaiss_avx2.ClusteringIterationStats_swigregister>),
#  ('ClusteringParameters', faiss.swigfaiss_avx2.ClusteringParameters),
#  ('ClusteringParameters_swigregister',
#   <function faiss._swigfaiss_avx2.ClusteringParameters_swigregister>),
#  ('Clustering_swigregister',
#   <function faiss._swigfaiss_avx2.Clustering_swigregister>),
#  ('ConcatenatedInvertedLists', faiss.swigfaiss_avx2.HStackInvertedLists),
#  ('Device', 1),
#  ('DirectMap', faiss.swigfaiss_avx2.DirectMap),
#  ('DirectMapAdd', faiss.swigfaiss_avx2.DirectMapAdd),
#  ('DirectMapAdd_swigregister',
#   <function faiss._swigfaiss_avx2.DirectMapAdd_swigregister>),
#  ('DirectMap_swigregister',
#   <function faiss._swigfaiss_avx2.DirectMap_swigregister>),
#  ('DistanceComputer', faiss.swigfaiss_avx2.DistanceComputer),
#  ('DistanceComputer_swigregister',
#   <function faiss._swigfaiss_avx2.DistanceComputer_swigregister>),
#  ('DistanceDataType_F16', 2),
#  ('DistanceDataType_F32', 1),
#  ('DoubleVector', faiss.swigfaiss_avx2.DoubleVector),
#  ('DoubleVector_swigregister',
#   <function faiss._swigfaiss_avx2.DoubleVector_swigregister>),
#  ('EnumeratedVectors', faiss.swigfaiss_avx2.EnumeratedVectors),
#  ('EnumeratedVectors_swigregister',
#   <function faiss._swigfaiss_avx2.EnumeratedVectors_swigregister>),
#  ('FAISS_VERSION_MAJOR', 1),
#  ('FAISS_VERSION_MINOR', 6),
#  ('FAISS_VERSION_PATCH', 3),
#  ('FileIOReader', faiss.swigfaiss_avx2.FileIOReader),
#  ('FileIOReader_swigregister',
#   <function faiss._swigfaiss_avx2.FileIOReader_swigregister>),
#  ('FileIOWriter', faiss.swigfaiss_avx2.FileIOWriter),
#  ('FileIOWriter_swigregister',
#   <function faiss._swigfaiss_avx2.FileIOWriter_swigregister>),
#  ('FloatVector', faiss.swigfaiss_avx2.FloatVector),
#  ('FloatVectorVector', faiss.swigfaiss_avx2.FloatVectorVector),
#  ('FloatVectorVector_swigregister',
#   <function faiss._swigfaiss_avx2.FloatVectorVector_swigregister>),
#  ('FloatVector_swigregister',
#   <function faiss._swigfaiss_avx2.FloatVector_swigregister>),
#  ('GpuClonerOptions', faiss.swigfaiss_avx2.GpuClonerOptions),
#  ('GpuClonerOptions_swigregister',
#   <function faiss._swigfaiss_avx2.GpuClonerOptions_swigregister>),
#  ('GpuDistanceParams', faiss.swigfaiss_avx2.GpuDistanceParams),
#  ('GpuDistanceParams_swigregister',
#   <function faiss._swigfaiss_avx2.GpuDistanceParams_swigregister>),
#  ('GpuIndex', faiss.swigfaiss_avx2.GpuIndex),
#  ('GpuIndexBinaryFlat', faiss.swigfaiss_avx2.GpuIndexBinaryFlat),
#  ('GpuIndexBinaryFlatConfig', faiss.swigfaiss_avx2.GpuIndexBinaryFlatConfig),
#  ('GpuIndexBinaryFlatConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexBinaryFlatConfig_swigregister>),
#  ('GpuIndexBinaryFlat_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexBinaryFlat_swigregister>),
#  ('GpuIndexConfig', faiss.swigfaiss_avx2.GpuIndexConfig),
#  ('GpuIndexConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexConfig_swigregister>),
#  ('GpuIndexFlat', faiss.swigfaiss_avx2.GpuIndexFlat),
#  ('GpuIndexFlatConfig', faiss.swigfaiss_avx2.GpuIndexFlatConfig),
#  ('GpuIndexFlatConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexFlatConfig_swigregister>),
#  ('GpuIndexFlatIP', faiss.swigfaiss_avx2.GpuIndexFlatIP),
#  ('GpuIndexFlatIP_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexFlatIP_swigregister>),
#  ('GpuIndexFlatL2', faiss.swigfaiss_avx2.GpuIndexFlatL2),
#  ('GpuIndexFlatL2_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexFlatL2_swigregister>),
#  ('GpuIndexFlat_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexFlat_swigregister>),
#  ('GpuIndexIVF', faiss.swigfaiss_avx2.GpuIndexIVF),
#  ('GpuIndexIVFConfig', faiss.swigfaiss_avx2.GpuIndexIVFConfig),
#  ('GpuIndexIVFConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFConfig_swigregister>),
#  ('GpuIndexIVFFlat', faiss.swigfaiss_avx2.GpuIndexIVFFlat),
#  ('GpuIndexIVFFlatConfig', faiss.swigfaiss_avx2.GpuIndexIVFFlatConfig),
#  ('GpuIndexIVFFlatConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFFlatConfig_swigregister>),
#  ('GpuIndexIVFFlat_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFFlat_swigregister>),
#  ('GpuIndexIVFPQ', faiss.swigfaiss_avx2.GpuIndexIVFPQ),
#  ('GpuIndexIVFPQConfig', faiss.swigfaiss_avx2.GpuIndexIVFPQConfig),
#  ('GpuIndexIVFPQConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFPQConfig_swigregister>),
#  ('GpuIndexIVFPQ_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFPQ_swigregister>),
#  ('GpuIndexIVFScalarQuantizer',
#   faiss.swigfaiss_avx2.GpuIndexIVFScalarQuantizer),
#  ('GpuIndexIVFScalarQuantizerConfig',
#   faiss.swigfaiss_avx2.GpuIndexIVFScalarQuantizerConfig),
#  ('GpuIndexIVFScalarQuantizerConfig_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFScalarQuantizerConfig_swigregister>),
#  ('GpuIndexIVFScalarQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVFScalarQuantizer_swigregister>),
#  ('GpuIndexIVF_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndexIVF_swigregister>),
#  ('GpuIndex_swigregister',
#   <function faiss._swigfaiss_avx2.GpuIndex_swigregister>),
#  ('GpuMultipleClonerOptions', faiss.swigfaiss_avx2.GpuMultipleClonerOptions),
#  ('GpuMultipleClonerOptions_swigregister',
#   <function faiss._swigfaiss_avx2.GpuMultipleClonerOptions_swigregister>),
#  ('GpuParameterSpace', faiss.swigfaiss_avx2.GpuParameterSpace),
#  ('GpuParameterSpace_swigregister',
#   <function faiss._swigfaiss_avx2.GpuParameterSpace_swigregister>),
#  ('GpuResources', faiss.swigfaiss_avx2.GpuResources),
#  ('GpuResourcesVector', faiss.swigfaiss_avx2.GpuResourcesVector),
#  ('GpuResourcesVector_swigregister',
#   <function faiss._swigfaiss_avx2.GpuResourcesVector_swigregister>),
#  ('GpuResources_swigregister',
#   <function faiss._swigfaiss_avx2.GpuResources_swigregister>),
#  ('HNSW', faiss.swigfaiss_avx2.HNSW),
#  ('HNSWStats', faiss.swigfaiss_avx2.HNSWStats),
#  ('HNSWStats_swigregister',
#   <function faiss._swigfaiss_avx2.HNSWStats_swigregister>),
#  ('HNSW_shrink_neighbor_list',
#   <function faiss._swigfaiss_avx2.HNSW_shrink_neighbor_list>),
#  ('HNSW_swigregister', <function faiss._swigfaiss_avx2.HNSW_swigregister>),
#  ('HStackInvertedLists', faiss.swigfaiss_avx2.HStackInvertedLists),
#  ('HStackInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.HStackInvertedLists_swigregister>),
#  ('HostPinned', 3),
#  ('IDSelector', faiss.swigfaiss_avx2.IDSelector),
#  ('IDSelectorArray', faiss.swigfaiss_avx2.IDSelectorArray),
#  ('IDSelectorArray_swigregister',
#   <function faiss._swigfaiss_avx2.IDSelectorArray_swigregister>),
#  ('IDSelectorBatch', faiss.swigfaiss_avx2.IDSelectorBatch),
#  ('IDSelectorBatch_swigregister',
#   <function faiss._swigfaiss_avx2.IDSelectorBatch_swigregister>),
#  ('IDSelectorRange', faiss.swigfaiss_avx2.IDSelectorRange),
#  ('IDSelectorRange_swigregister',
#   <function faiss._swigfaiss_avx2.IDSelectorRange_swigregister>),
#  ('IDSelector_swigregister',
#   <function faiss._swigfaiss_avx2.IDSelector_swigregister>),
#  ('INDICES_32_BIT', 2),
#  ('INDICES_64_BIT', 3),
#  ('INDICES_CPU', 0),
#  ('INDICES_IVF', 1),
#  ('IOReader', faiss.swigfaiss_avx2.IOReader),
#  ('IOReader_swigregister',
#   <function faiss._swigfaiss_avx2.IOReader_swigregister>),
#  ('IOWriter', faiss.swigfaiss_avx2.IOWriter),
#  ('IOWriter_swigregister',
#   <function faiss._swigfaiss_avx2.IOWriter_swigregister>),
#  ('IO_FLAG_MMAP', 1),
#  ('IO_FLAG_ONDISK_SAME_DIR', 4),
#  ('IO_FLAG_READ_ONLY', 2),
#  ('ITQMatrix', faiss.swigfaiss_avx2.ITQMatrix),
#  ('ITQMatrix_swigregister',
#   <function faiss._swigfaiss_avx2.ITQMatrix_swigregister>),
#  ('ITQTransform', faiss.swigfaiss_avx2.ITQTransform),
#  ('ITQTransform_swigregister',
#   <function faiss._swigfaiss_avx2.ITQTransform_swigregister>),
#  ('IVFPQSearchParameters', faiss.swigfaiss_avx2.IVFPQSearchParameters),
#  ('IVFPQSearchParameters_swigregister',
#   <function faiss._swigfaiss_avx2.IVFPQSearchParameters_swigregister>),
#  ('IVFSearchParameters', faiss.swigfaiss_avx2.IVFSearchParameters),
#  ('IVFSearchParameters_swigregister',
#   <function faiss._swigfaiss_avx2.IVFSearchParameters_swigregister>),
#  ('Index', faiss.swigfaiss_avx2.Index),
#  ('Index2Layer', faiss.swigfaiss_avx2.Index2Layer),
#  ('Index2Layer_swigregister',
#   <function faiss._swigfaiss_avx2.Index2Layer_swigregister>),
#  ('IndexBinary', faiss.swigfaiss_avx2.IndexBinary),
#  ('IndexBinaryFlat', faiss.swigfaiss_avx2.IndexBinaryFlat),
#  ('IndexBinaryFlat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryFlat_swigregister>),
#  ('IndexBinaryFromFloat', faiss.swigfaiss_avx2.IndexBinaryFromFloat),
#  ('IndexBinaryFromFloat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryFromFloat_swigregister>),
#  ('IndexBinaryHNSW', faiss.swigfaiss_avx2.IndexBinaryHNSW),
#  ('IndexBinaryHNSW_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryHNSW_swigregister>),
#  ('IndexBinaryHash', faiss.swigfaiss_avx2.IndexBinaryHash),
#  ('IndexBinaryHashStats', faiss.swigfaiss_avx2.IndexBinaryHashStats),
#  ('IndexBinaryHashStats_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryHashStats_swigregister>),
#  ('IndexBinaryHash_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryHash_swigregister>),
#  ('IndexBinaryIDMap', faiss.swigfaiss_avx2.IndexBinaryIDMap),
#  ('IndexBinaryIDMap2', faiss.swigfaiss_avx2.IndexBinaryIDMap2),
#  ('IndexBinaryIDMap2_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryIDMap2_swigregister>),
#  ('IndexBinaryIDMap_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryIDMap_swigregister>),
#  ('IndexBinaryIVF', faiss.swigfaiss_avx2.IndexBinaryIVF),
#  ('IndexBinaryIVF_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryIVF_swigregister>),
#  ('IndexBinaryMultiHash', faiss.swigfaiss_avx2.IndexBinaryMultiHash),
#  ('IndexBinaryMultiHash_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryMultiHash_swigregister>),
#  ('IndexBinaryReplicas', faiss.swigfaiss_avx2.IndexBinaryReplicas),
#  ('IndexBinaryReplicas_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryReplicas_swigregister>),
#  ('IndexBinaryShards', faiss.swigfaiss_avx2.IndexBinaryShards),
#  ('IndexBinaryShards_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinaryShards_swigregister>),
#  ('IndexBinary_swigregister',
#   <function faiss._swigfaiss_avx2.IndexBinary_swigregister>),
#  ('IndexFlat', faiss.swigfaiss_avx2.IndexFlat),
#  ('IndexFlat1D', faiss.swigfaiss_avx2.IndexFlat1D),
#  ('IndexFlat1D_swigregister',
#   <function faiss._swigfaiss_avx2.IndexFlat1D_swigregister>),
#  ('IndexFlatIP', faiss.swigfaiss_avx2.IndexFlatIP),
#  ('IndexFlatIP_swigregister',
#   <function faiss._swigfaiss_avx2.IndexFlatIP_swigregister>),
#  ('IndexFlatL2', faiss.swigfaiss_avx2.IndexFlatL2),
#  ('IndexFlatL2BaseShift', faiss.swigfaiss_avx2.IndexFlatL2BaseShift),
#  ('IndexFlatL2BaseShift_swigregister',
#   <function faiss._swigfaiss_avx2.IndexFlatL2BaseShift_swigregister>),
#  ('IndexFlatL2_swigregister',
#   <function faiss._swigfaiss_avx2.IndexFlatL2_swigregister>),
#  ('IndexFlat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexFlat_swigregister>),
#  ('IndexHNSW', faiss.swigfaiss_avx2.IndexHNSW),
#  ('IndexHNSW2Level', faiss.swigfaiss_avx2.IndexHNSW2Level),
#  ('IndexHNSW2Level_swigregister',
#   <function faiss._swigfaiss_avx2.IndexHNSW2Level_swigregister>),
#  ('IndexHNSWFlat', faiss.swigfaiss_avx2.IndexHNSWFlat),
#  ('IndexHNSWFlat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexHNSWFlat_swigregister>),
#  ('IndexHNSWPQ', faiss.swigfaiss_avx2.IndexHNSWPQ),
#  ('IndexHNSWPQ_swigregister',
#   <function faiss._swigfaiss_avx2.IndexHNSWPQ_swigregister>),
#  ('IndexHNSWSQ', faiss.swigfaiss_avx2.IndexHNSWSQ),
#  ('IndexHNSWSQ_swigregister',
#   <function faiss._swigfaiss_avx2.IndexHNSWSQ_swigregister>),
#  ('IndexHNSW_swigregister',
#   <function faiss._swigfaiss_avx2.IndexHNSW_swigregister>),
#  ('IndexIDMap', faiss.swigfaiss_avx2.IndexIDMap),
#  ('IndexIDMap2', faiss.swigfaiss_avx2.IndexIDMap2),
#  ('IndexIDMap2_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIDMap2_swigregister>),
#  ('IndexIDMap_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIDMap_swigregister>),
#  ('IndexIVF', faiss.swigfaiss_avx2.IndexIVF),
#  ('IndexIVFFlat', faiss.swigfaiss_avx2.IndexIVFFlat),
#  ('IndexIVFFlatDedup', faiss.swigfaiss_avx2.IndexIVFFlatDedup),
#  ('IndexIVFFlatDedup_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFFlatDedup_swigregister>),
#  ('IndexIVFFlat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFFlat_swigregister>),
#  ('IndexIVFPQ', faiss.swigfaiss_avx2.IndexIVFPQ),
#  ('IndexIVFPQR', faiss.swigfaiss_avx2.IndexIVFPQR),
#  ('IndexIVFPQR_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFPQR_swigregister>),
#  ('IndexIVFPQStats', faiss.swigfaiss_avx2.IndexIVFPQStats),
#  ('IndexIVFPQStats_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFPQStats_swigregister>),
#  ('IndexIVFPQ_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFPQ_swigregister>),
#  ('IndexIVFScalarQuantizer', faiss.swigfaiss_avx2.IndexIVFScalarQuantizer),
#  ('IndexIVFScalarQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFScalarQuantizer_swigregister>),
#  ('IndexIVFSpectralHash', faiss.swigfaiss_avx2.IndexIVFSpectralHash),
#  ('IndexIVFSpectralHash_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFSpectralHash_swigregister>),
#  ('IndexIVFStats', faiss.swigfaiss_avx2.IndexIVFStats),
#  ('IndexIVFStats_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVFStats_swigregister>),
#  ('IndexIVF_swigregister',
#   <function faiss._swigfaiss_avx2.IndexIVF_swigregister>),
#  ('IndexLSH', faiss.swigfaiss_avx2.IndexLSH),
#  ('IndexLSH_swigregister',
#   <function faiss._swigfaiss_avx2.IndexLSH_swigregister>),
#  ('IndexLattice', faiss.swigfaiss_avx2.IndexLattice),
#  ('IndexLattice_swigregister',
#   <function faiss._swigfaiss_avx2.IndexLattice_swigregister>),
#  ('IndexPQ', faiss.swigfaiss_avx2.IndexPQ),
#  ('IndexPQStats', faiss.swigfaiss_avx2.IndexPQStats),
#  ('IndexPQStats_swigregister',
#   <function faiss._swigfaiss_avx2.IndexPQStats_swigregister>),
#  ('IndexPQ_swigregister',
#   <function faiss._swigfaiss_avx2.IndexPQ_swigregister>),
#  ('IndexPreTransform', faiss.swigfaiss_avx2.IndexPreTransform),
#  ('IndexPreTransform_swigregister',
#   <function faiss._swigfaiss_avx2.IndexPreTransform_swigregister>),
#  ('IndexProxy', faiss.swigfaiss_avx2.IndexReplicas),
#  ('IndexRefineFlat', faiss.swigfaiss_avx2.IndexRefineFlat),
#  ('IndexRefineFlat_swigregister',
#   <function faiss._swigfaiss_avx2.IndexRefineFlat_swigregister>),
#  ('IndexReplicas', faiss.swigfaiss_avx2.IndexReplicas),
#  ('IndexReplicas_swigregister',
#   <function faiss._swigfaiss_avx2.IndexReplicas_swigregister>),
#  ('IndexScalarQuantizer', faiss.swigfaiss_avx2.IndexScalarQuantizer),
#  ('IndexScalarQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.IndexScalarQuantizer_swigregister>),
#  ('IndexShards', faiss.swigfaiss_avx2.IndexShards),
#  ('IndexShards_swigregister',
#   <function faiss._swigfaiss_avx2.IndexShards_swigregister>),
#  ('IndexSplitVectors', faiss.swigfaiss_avx2.IndexSplitVectors),
#  ('IndexSplitVectors_swigregister',
#   <function faiss._swigfaiss_avx2.IndexSplitVectors_swigregister>),
#  ('Index_swigregister', <function faiss._swigfaiss_avx2.Index_swigregister>),
#  ('IntVector', faiss.swigfaiss_avx2.IntVector),
#  ('IntVector_swigregister',
#   <function faiss._swigfaiss_avx2.IntVector_swigregister>),
#  ('InterruptCallback', faiss.swigfaiss_avx2.InterruptCallback),
#  ('InterruptCallback_check',
#   <function faiss._swigfaiss_avx2.InterruptCallback_check>),
#  ('InterruptCallback_clear_instance',
#   <function faiss._swigfaiss_avx2.InterruptCallback_clear_instance>),
#  ('InterruptCallback_get_period_hint',
#   <function faiss._swigfaiss_avx2.InterruptCallback_get_period_hint>),
#  ('InterruptCallback_is_interrupted',
#   <function faiss._swigfaiss_avx2.InterruptCallback_is_interrupted>),
#  ('InterruptCallback_swigregister',
#   <function faiss._swigfaiss_avx2.InterruptCallback_swigregister>),
#  ('IntersectionCriterion', faiss.swigfaiss_avx2.IntersectionCriterion),
#  ('IntersectionCriterion_swigregister',
#   <function faiss._swigfaiss_avx2.IntersectionCriterion_swigregister>),
#  ('InvertedLists', faiss.swigfaiss_avx2.InvertedLists),
#  ('InvertedListsPtrVector', faiss.swigfaiss_avx2.InvertedListsPtrVector),
#  ('InvertedListsPtrVector_swigregister',
#   <function faiss._swigfaiss_avx2.InvertedListsPtrVector_swigregister>),
#  ('InvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.InvertedLists_swigregister>),
#  ('Kmeans', faiss.Kmeans),
#  ('Level1Quantizer', faiss.swigfaiss_avx2.Level1Quantizer),
#  ('Level1Quantizer_swigregister',
#   <function faiss._swigfaiss_avx2.Level1Quantizer_swigregister>),
#  ('LinearTransform', faiss.swigfaiss_avx2.LinearTransform),
#  ('LinearTransform_swigregister',
#   <function faiss._swigfaiss_avx2.LinearTransform_swigregister>),
#  ('LongLongVector', faiss.swigfaiss_avx2.LongLongVector),
#  ('LongLongVector_swigregister',
#   <function faiss._swigfaiss_avx2.LongLongVector_swigregister>),
#  ('LongVector', faiss.swigfaiss_avx2.LongVector),
#  ('LongVectorVector', faiss.swigfaiss_avx2.LongVectorVector),
#  ('LongVectorVector_swigregister',
#   <function faiss._swigfaiss_avx2.LongVectorVector_swigregister>),
#  ('LongVector_swigregister',
#   <function faiss._swigfaiss_avx2.LongVector_swigregister>),
#  ('METRIC_BrayCurtis', 21),
#  ('METRIC_Canberra', 20),
#  ('METRIC_INNER_PRODUCT', 0),
#  ('METRIC_JensenShannon', 22),
#  ('METRIC_L1', 2),
#  ('METRIC_L2', 1),
#  ('METRIC_Linf', 3),
#  ('METRIC_Lp', 4),
#  ('MapLong2Long', faiss.swigfaiss_avx2.MapLong2Long),
#  ('MapLong2Long_swigregister',
#   <function faiss._swigfaiss_avx2.MapLong2Long_swigregister>),
#  ('MaskedInvertedLists', faiss.swigfaiss_avx2.MaskedInvertedLists),
#  ('MaskedInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.MaskedInvertedLists_swigregister>),
#  ('MatrixStats', faiss.swigfaiss_avx2.MatrixStats),
#  ('MatrixStats_swigregister',
#   <function faiss._swigfaiss_avx2.MatrixStats_swigregister>),
#  ('MultiIndexQuantizer', faiss.swigfaiss_avx2.MultiIndexQuantizer),
#  ('MultiIndexQuantizer2', faiss.swigfaiss_avx2.MultiIndexQuantizer2),
#  ('MultiIndexQuantizer2_swigregister',
#   <function faiss._swigfaiss_avx2.MultiIndexQuantizer2_swigregister>),
#  ('MultiIndexQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.MultiIndexQuantizer_swigregister>),
#  ('NormalizationTransform', faiss.swigfaiss_avx2.NormalizationTransform),
#  ('NormalizationTransform_swigregister',
#   <function faiss._swigfaiss_avx2.NormalizationTransform_swigregister>),
#  ('OPQMatrix', faiss.swigfaiss_avx2.OPQMatrix),
#  ('OPQMatrix_swigregister',
#   <function faiss._swigfaiss_avx2.OPQMatrix_swigregister>),
#  ('OnDiskInvertedLists', faiss.swigfaiss_avx2.OnDiskInvertedLists),
#  ('OnDiskInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.OnDiskInvertedLists_swigregister>),
#  ('OneRecallAtRCriterion', faiss.swigfaiss_avx2.OneRecallAtRCriterion),
#  ('OneRecallAtRCriterion_swigregister',
#   <function faiss._swigfaiss_avx2.OneRecallAtRCriterion_swigregister>),
#  ('OperatingPoint', faiss.swigfaiss_avx2.OperatingPoint),
#  ('OperatingPointVector', faiss.swigfaiss_avx2.OperatingPointVector),
#  ('OperatingPointVector_swigregister',
#   <function faiss._swigfaiss_avx2.OperatingPointVector_swigregister>),
#  ('OperatingPoint_swigregister',
#   <function faiss._swigfaiss_avx2.OperatingPoint_swigregister>),
#  ('OperatingPoints', faiss.swigfaiss_avx2.OperatingPoints),
#  ('OperatingPoints_swigregister',
#   <function faiss._swigfaiss_avx2.OperatingPoints_swigregister>),
#  ('PCAMatrix', faiss.swigfaiss_avx2.PCAMatrix),
#  ('PCAMatrix_swigregister',
#   <function faiss._swigfaiss_avx2.PCAMatrix_swigregister>),
#  ('PQDecoder16', faiss.swigfaiss_avx2.PQDecoder16),
#  ('PQDecoder16_swigregister',
#   <function faiss._swigfaiss_avx2.PQDecoder16_swigregister>),
#  ('PQDecoder8', faiss.swigfaiss_avx2.PQDecoder8),
#  ('PQDecoder8_swigregister',
#   <function faiss._swigfaiss_avx2.PQDecoder8_swigregister>),
#  ('PQDecoderGeneric', faiss.swigfaiss_avx2.PQDecoderGeneric),
#  ('PQDecoderGeneric_swigregister',
#   <function faiss._swigfaiss_avx2.PQDecoderGeneric_swigregister>),
#  ('PQEncoder16', faiss.swigfaiss_avx2.PQEncoder16),
#  ('PQEncoder16_swigregister',
#   <function faiss._swigfaiss_avx2.PQEncoder16_swigregister>),
#  ('PQEncoder8', faiss.swigfaiss_avx2.PQEncoder8),
#  ('PQEncoder8_swigregister',
#   <function faiss._swigfaiss_avx2.PQEncoder8_swigregister>),
#  ('PQEncoderGeneric', faiss.swigfaiss_avx2.PQEncoderGeneric),
#  ('PQEncoderGeneric_swigregister',
#   <function faiss._swigfaiss_avx2.PQEncoderGeneric_swigregister>),
#  ('ParameterRange', faiss.swigfaiss_avx2.ParameterRange),
#  ('ParameterRange_swigregister',
#   <function faiss._swigfaiss_avx2.ParameterRange_swigregister>),
#  ('ParameterSpace', faiss.swigfaiss_avx2.ParameterSpace),
#  ('ParameterSpace_swigregister',
#   <function faiss._swigfaiss_avx2.ParameterSpace_swigregister>),
#  ('PermutationObjective', faiss.swigfaiss_avx2.PermutationObjective),
#  ('PermutationObjective_swigregister',
#   <function faiss._swigfaiss_avx2.PermutationObjective_swigregister>),
#  ('PolysemousTraining', faiss.swigfaiss_avx2.PolysemousTraining),
#  ('PolysemousTraining_swigregister',
#   <function faiss._swigfaiss_avx2.PolysemousTraining_swigregister>),
#  ('ProductQuantizer', faiss.swigfaiss_avx2.ProductQuantizer),
#  ('ProductQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.ProductQuantizer_swigregister>),
#  ('PyCallbackIOReader', faiss.swigfaiss_avx2.PyCallbackIOReader),
#  ('PyCallbackIOReader_swigregister',
#   <function faiss._swigfaiss_avx2.PyCallbackIOReader_swigregister>),
#  ('PyCallbackIOWriter', faiss.swigfaiss_avx2.PyCallbackIOWriter),
#  ('PyCallbackIOWriter_swigregister',
#   <function faiss._swigfaiss_avx2.PyCallbackIOWriter_swigregister>),
#  ('RandomGenerator', faiss.swigfaiss_avx2.RandomGenerator),
#  ('RandomGenerator_swigregister',
#   <function faiss._swigfaiss_avx2.RandomGenerator_swigregister>),
#  ('RandomRotationMatrix', faiss.swigfaiss_avx2.RandomRotationMatrix),
#  ('RandomRotationMatrix_swigregister',
#   <function faiss._swigfaiss_avx2.RandomRotationMatrix_swigregister>),
#  ('RangeQueryResult', faiss.swigfaiss_avx2.RangeQueryResult),
#  ('RangeQueryResult_swigregister',
#   <function faiss._swigfaiss_avx2.RangeQueryResult_swigregister>),
#  ('RangeSearchPartialResult', faiss.swigfaiss_avx2.RangeSearchPartialResult),
#  ('RangeSearchPartialResult_merge',
#   <function faiss._swigfaiss_avx2.RangeSearchPartialResult_merge>),
#  ('RangeSearchPartialResult_swigregister',
#   <function faiss._swigfaiss_avx2.RangeSearchPartialResult_swigregister>),
#  ('RangeSearchResult', faiss.swigfaiss_avx2.RangeSearchResult),
#  ('RangeSearchResult_swigregister',
#   <function faiss._swigfaiss_avx2.RangeSearchResult_swigregister>),
#  ('ReadOnlyInvertedLists', faiss.swigfaiss_avx2.ReadOnlyInvertedLists),
#  ('ReadOnlyInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.ReadOnlyInvertedLists_swigregister>),
#  ('ReconstructFromNeighbors', faiss.swigfaiss_avx2.ReconstructFromNeighbors),
#  ('ReconstructFromNeighbors_swigregister',
#   <function faiss._swigfaiss_avx2.ReconstructFromNeighbors_swigregister>),
#  ('RemapDimensionsTransform', faiss.swigfaiss_avx2.RemapDimensionsTransform),
#  ('RemapDimensionsTransform_swigregister',
#   <function faiss._swigfaiss_avx2.RemapDimensionsTransform_swigregister>),
#  ('Repeat', faiss.swigfaiss_avx2.Repeat),
#  ('RepeatVector', faiss.swigfaiss_avx2.RepeatVector),
#  ('RepeatVector_swigregister',
#   <function faiss._swigfaiss_avx2.RepeatVector_swigregister>),
#  ('Repeat_swigregister', <function faiss._swigfaiss_avx2.Repeat_swigregister>),
#  ('Repeats', faiss.swigfaiss_avx2.Repeats),
#  ('Repeats_swigregister',
#   <function faiss._swigfaiss_avx2.Repeats_swigregister>),
#  ('ReproduceDistancesObjective',
#   faiss.swigfaiss_avx2.ReproduceDistancesObjective),
#  ('ReproduceDistancesObjective_compute_mean_stdev',
#   <function faiss._swigfaiss_avx2.ReproduceDistancesObjective_compute_mean_stdev>),
#  ('ReproduceDistancesObjective_sqr',
#   <function faiss._swigfaiss_avx2.ReproduceDistancesObjective_sqr>),
#  ('ReproduceDistancesObjective_swigregister',
#   <function faiss._swigfaiss_avx2.ReproduceDistancesObjective_swigregister>),
#  ('ResultHeap', faiss.ResultHeap),
#  ('ScalarQuantizer', faiss.swigfaiss_avx2.ScalarQuantizer),
#  ('ScalarQuantizer_swigregister',
#   <function faiss._swigfaiss_avx2.ScalarQuantizer_swigregister>),
#  ('SimulatedAnnealingOptimizer',
#   faiss.swigfaiss_avx2.SimulatedAnnealingOptimizer),
#  ('SimulatedAnnealingOptimizer_swigregister',
#   <function faiss._swigfaiss_avx2.SimulatedAnnealingOptimizer_swigregister>),
#  ('SimulatedAnnealingParameters',
#   faiss.swigfaiss_avx2.SimulatedAnnealingParameters),
#  ('SimulatedAnnealingParameters_swigregister',
#   <function faiss._swigfaiss_avx2.SimulatedAnnealingParameters_swigregister>),
#  ('SliceInvertedLists', faiss.swigfaiss_avx2.SliceInvertedLists),
#  ('SliceInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.SliceInvertedLists_swigregister>),
#  ('SlidingIndexWindow', faiss.swigfaiss_avx2.SlidingIndexWindow),
#  ('SlidingIndexWindow_swigregister',
#   <function faiss._swigfaiss_avx2.SlidingIndexWindow_swigregister>),
#  ('StandardGpuResources', faiss.swigfaiss_avx2.StandardGpuResources),
#  ('StandardGpuResources_swigregister',
#   <function faiss._swigfaiss_avx2.StandardGpuResources_swigregister>),
#  ('ThreadedIndexBase', faiss.swigfaiss_avx2.ThreadedIndexBase),
#  ('ThreadedIndexBaseBinary', faiss.swigfaiss_avx2.ThreadedIndexBaseBinary),
#  ('ThreadedIndexBaseBinary_swigregister',
#   <function faiss._swigfaiss_avx2.ThreadedIndexBaseBinary_swigregister>),
#  ('ThreadedIndexBase_swigregister',
#   <function faiss._swigfaiss_avx2.ThreadedIndexBase_swigregister>),
#  ('ToCPUCloner', faiss.swigfaiss_avx2.ToCPUCloner),
#  ('ToCPUCloner_swigregister',
#   <function faiss._swigfaiss_avx2.ToCPUCloner_swigregister>),
#  ('ToGpuCloner', faiss.swigfaiss_avx2.ToGpuCloner),
#  ('ToGpuClonerMultiple', faiss.swigfaiss_avx2.ToGpuClonerMultiple),
#  ('ToGpuClonerMultiple_swigregister',
#   <function faiss._swigfaiss_avx2.ToGpuClonerMultiple_swigregister>),
#  ('ToGpuCloner_swigregister',
#   <function faiss._swigfaiss_avx2.ToGpuCloner_swigregister>),
#  ('Uint64Vector', faiss.swigfaiss_avx2.Uint64Vector),
#  ('Uint64Vector_swigregister',
#   <function faiss._swigfaiss_avx2.Uint64Vector_swigregister>),
#  ('Unified', 2),
#  ('VStackInvertedLists', faiss.swigfaiss_avx2.VStackInvertedLists),
#  ('VStackInvertedLists_swigregister',
#   <function faiss._swigfaiss_avx2.VStackInvertedLists_swigregister>),
#  ('VectorIOReader', faiss.swigfaiss_avx2.VectorIOReader),
#  ('VectorIOReader_swigregister',
#   <function faiss._swigfaiss_avx2.VectorIOReader_swigregister>),
#  ('VectorIOWriter', faiss.swigfaiss_avx2.VectorIOWriter),
#  ('VectorIOWriter_swigregister',
#   <function faiss._swigfaiss_avx2.VectorIOWriter_swigregister>),
#  ('VectorTransform', faiss.swigfaiss_avx2.VectorTransform),
#  ('VectorTransformVector', faiss.swigfaiss_avx2.VectorTransformVector),
#  ('VectorTransformVector_swigregister',
#   <function faiss._swigfaiss_avx2.VectorTransformVector_swigregister>),
#  ('VectorTransform_swigregister',
#   <function faiss._swigfaiss_avx2.VectorTransform_swigregister>),
#  ('VisitedTable', faiss.swigfaiss_avx2.VisitedTable),
#  ('VisitedTable_swigregister',
#   <function faiss._swigfaiss_avx2.VisitedTable_swigregister>),
#  ('ZnSphereCodec', faiss.swigfaiss_avx2.ZnSphereCodec),
#  ('ZnSphereCodecAlt', faiss.swigfaiss_avx2.ZnSphereCodecAlt),
#  ('ZnSphereCodecAlt_swigregister',
#   <function faiss._swigfaiss_avx2.ZnSphereCodecAlt_swigregister>),
#  ('ZnSphereCodecRec', faiss.swigfaiss_avx2.ZnSphereCodecRec),
#  ('ZnSphereCodecRec_swigregister',
#   <function faiss._swigfaiss_avx2.ZnSphereCodecRec_swigregister>),
#  ('ZnSphereCodec_swigregister',
#   <function faiss._swigfaiss_avx2.ZnSphereCodec_swigregister>),
#  ('ZnSphereSearch', faiss.swigfaiss_avx2.ZnSphereSearch),
#  ('ZnSphereSearch_swigregister',
#   <function faiss._swigfaiss_avx2.ZnSphereSearch_swigregister>),
#  ('__builtins__',
#   {'__name__': 'builtins',
#    '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#    '__package__': '',
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#    '__build_class__': <function __build_class__>,
#    '__import__': <function __import__>,
#    'abs': <function abs>,
#    'all': <function all>,
#    'any': <function any>,
#    'ascii': <function ascii>,
#    'bin': <function bin>,
#    'breakpoint': <function breakpoint>,
#    'callable': <function callable>,
#    'chr': <function chr>,
#    'compile': <function compile>,
#    'delattr': <function delattr>,
#    'dir': <function dir>,
#    'divmod': <function divmod>,
#    'eval': <function eval>,
#    'exec': <function exec>,
#    'format': <function format>,
#    'getattr': <function getattr>,
#    'globals': <function globals>,
#    'hasattr': <function hasattr>,
#    'hash': <function hash>,
#    'hex': <function hex>,
#    'id': <function id>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fd4eb4bff90>>,
#    'isinstance': <function isinstance>,
#    'issubclass': <function issubclass>,
#    'iter': <function iter>,
#    'len': <function len>,
#    'locals': <function locals>,
#    'max': <function max>,
#    'min': <function min>,
#    'next': <function next>,
#    'oct': <function oct>,
#    'ord': <function ord>,
#    'pow': <function pow>,
#    'print': <function print>,
#    'repr': <function repr>,
#    'round': <function round>,
#    'setattr': <function setattr>,
#    'sorted': <function sorted>,
#    'sum': <function sum>,
#    'vars': <function vars>,
#    'None': None,
#    'Ellipsis': Ellipsis,
#    'NotImplemented': NotImplemented,
#    'False': False,
#    'True': True,
#    'bool': bool,
#    'memoryview': memoryview,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'classmethod': classmethod,
#    'complex': complex,
#    'dict': dict,
#    'enumerate': enumerate,
#    'filter': filter,
#    'float': float,
#    'frozenset': frozenset,
#    'property': property,
#    'int': int,
#    'list': list,
#    'map': map,
#    'object': object,
#    'range': range,
#    'reversed': reversed,
#    'set': set,
#    'slice': slice,
#    'staticmethod': staticmethod,
#    'str': str,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'zip': zip,
#    '__debug__': True,
#    'BaseException': BaseException,
#    'Exception': Exception,
#    'TypeError': TypeError,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'GeneratorExit': GeneratorExit,
#    'SystemExit': SystemExit,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'ImportError': ImportError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'OSError': OSError,
#    'EnvironmentError': OSError,
#    'IOError': OSError,
#    'EOFError': EOFError,
#    'RuntimeError': RuntimeError,
#    'RecursionError': RecursionError,
#    'NotImplementedError': NotImplementedError,
#    'NameError': NameError,
#    'UnboundLocalError': UnboundLocalError,
#    'AttributeError': AttributeError,
#    'SyntaxError': SyntaxError,
#    'IndentationError': IndentationError,
#    'TabError': TabError,
#    'LookupError': LookupError,
#    'IndexError': IndexError,
#    'KeyError': KeyError,
#    'ValueError': ValueError,
#    'UnicodeError': UnicodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'AssertionError': AssertionError,
#    'ArithmeticError': ArithmeticError,
#    'FloatingPointError': FloatingPointError,
#    'OverflowError': OverflowError,
#    'ZeroDivisionError': ZeroDivisionError,
#    'SystemError': SystemError,
#    'ReferenceError': ReferenceError,
#    'MemoryError': MemoryError,
#    'BufferError': BufferError,
#    'Warning': Warning,
#    'UserWarning': UserWarning,
#    'DeprecationWarning': DeprecationWarning,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'SyntaxWarning': SyntaxWarning,
#    'RuntimeWarning': RuntimeWarning,
#    'FutureWarning': FutureWarning,
#    'ImportWarning': ImportWarning,
#    'UnicodeWarning': UnicodeWarning,
#    'BytesWarning': BytesWarning,
#    'ResourceWarning': ResourceWarning,
#    'ConnectionError': ConnectionError,
#    'BlockingIOError': BlockingIOError,
#    'BrokenPipeError': BrokenPipeError,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'IsADirectoryError': IsADirectoryError,
#    'NotADirectoryError': NotADirectoryError,
#    'InterruptedError': InterruptedError,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'TimeoutError': TimeoutError,
#    'open': <function io.open>,
#    'copyright': Copyright (c) 2001-2020 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#        for supporting Python development.  See www.python.org for more information.,
#    'license': Type license() to see the full license text,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    '__IPYTHON__': True,
#    'display': <function IPython.core.display.display>,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fd4eb4bf890>>,
#    'dreload': <function IPython.lib.deepreload._dreload>}),
#  ('__cached__',
#   '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/__pycache__/__init__.cpython-37.pyc'),
#  ('__doc__', None),
#  ('__file__',
#   '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/__init__.py'),
#  ('__loader__',
#   <_frozen_importlib_external.SourceFileLoader at 0x7fd4e83945d0>),
#  ('__name__', 'faiss'),
#  ('__package__', 'faiss'),
#  ('__path__',
#   ['/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss']),
#  ('__spec__',
#   ModuleSpec(name='faiss', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fd4e83945d0>, origin='/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/__init__.py', submodule_search_locations=['/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss'])),
#  ('__version__', '1.6.3'),
#  ('_swigfaiss_avx2',
#   <module 'faiss._swigfaiss_avx2' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/_swigfaiss_avx2.so'>),
#  ('add_ref_in_constructor', <function faiss.add_ref_in_constructor>),
#  ('add_ref_in_function', <function faiss.add_ref_in_function>),
#  ('add_ref_in_method', <function faiss.add_ref_in_method>),
#  ('allocMemorySpaceV', <function faiss._swigfaiss_avx2.allocMemorySpaceV>),
#  ('bfKnn', <function faiss._swigfaiss_avx2.bfKnn>),
#  ('binary_to_real', <function faiss._swigfaiss_avx2.binary_to_real>),
#  ('bincode_hist', <function faiss._swigfaiss_avx2.bincode_hist>),
#  ('bitvec_print', <function faiss._swigfaiss_avx2.bitvec_print>),
#  ('bitvec_shuffle', <function faiss._swigfaiss_avx2.bitvec_shuffle>),
#  ('bitvecs2fvecs', <function faiss._swigfaiss_avx2.bitvecs2fvecs>),
#  ('bruteForceKnn', <function faiss._swigfaiss_avx2.bruteForceKnn>),
#  ('byte_rand', <function faiss._swigfaiss_avx2.byte_rand>),
#  ('cast_integer_to_float_ptr',
#   <function faiss._swigfaiss_avx2.cast_integer_to_float_ptr>),
#  ('cast_integer_to_int_ptr',
#   <function faiss._swigfaiss_avx2.cast_integer_to_int_ptr>),
#  ('cast_integer_to_long_ptr',
#   <function faiss._swigfaiss_avx2.cast_integer_to_long_ptr>),
#  ('check_compatible_for_merge',
#   <function faiss._swigfaiss_avx2.check_compatible_for_merge>),
#  ('check_openmp', <function faiss._swigfaiss_avx2.check_openmp>),
#  ('clone_index', <function faiss._swigfaiss_avx2.clone_index>),
#  ('copy_array_to_vector', <function faiss.copy_array_to_vector>),
#  ('crosshamming_count_thres',
#   <function faiss._swigfaiss_avx2.crosshamming_count_thres>),
#  ('cvar', <Swig global variables>),
#  ('deserialize_index', <function faiss.deserialize_index>),
#  ('deserialize_index_binary', <function faiss.deserialize_index_binary>),
#  ('downcast_IndexBinary',
#   <function faiss._swigfaiss_avx2.downcast_IndexBinary>),
#  ('downcast_InvertedLists',
#   <function faiss._swigfaiss_avx2.downcast_InvertedLists>),
#  ('downcast_VectorTransform',
#   <function faiss._swigfaiss_avx2.downcast_VectorTransform>),
#  ('downcast_index', <function faiss._swigfaiss_avx2.downcast_index>),
#  ('eval_intersection', <function faiss.eval_intersection>),
#  ('extract_index_ivf', <function faiss._swigfaiss_avx2.extract_index_ivf>),
#  ('float_maxheap_array_t', faiss.swigfaiss_avx2.float_maxheap_array_t),
#  ('float_maxheap_array_t_swigregister',
#   <function faiss._swigfaiss_avx2.float_maxheap_array_t_swigregister>),
#  ('float_minheap_array_t', faiss.swigfaiss_avx2.float_minheap_array_t),
#  ('float_minheap_array_t_swigregister',
#   <function faiss._swigfaiss_avx2.float_minheap_array_t_swigregister>),
#  ('float_rand', <function faiss._swigfaiss_avx2.float_rand>),
#  ('float_randn', <function faiss._swigfaiss_avx2.float_randn>),
#  ('fourcc', <function faiss._swigfaiss_avx2.fourcc>),
#  ('freeMemorySpace', <function faiss._swigfaiss_avx2.freeMemorySpace>),
#  ('fvec2bitvec', <function faiss._swigfaiss_avx2.fvec2bitvec>),
#  ('fvec_L1', <function faiss._swigfaiss_avx2.fvec_L1>),
#  ('fvec_L2sqr', <function faiss._swigfaiss_avx2.fvec_L2sqr>),
#  ('fvec_L2sqr_by_idx', <function faiss._swigfaiss_avx2.fvec_L2sqr_by_idx>),
#  ('fvec_L2sqr_ny', <function faiss._swigfaiss_avx2.fvec_L2sqr_ny>),
#  ('fvec_Linf', <function faiss._swigfaiss_avx2.fvec_Linf>),
#  ('fvec_argsort', <function faiss._swigfaiss_avx2.fvec_argsort>),
#  ('fvec_argsort_parallel',
#   <function faiss._swigfaiss_avx2.fvec_argsort_parallel>),
#  ('fvec_inner_product', <function faiss._swigfaiss_avx2.fvec_inner_product>),
#  ('fvec_inner_products_by_idx',
#   <function faiss._swigfaiss_avx2.fvec_inner_products_by_idx>),
#  ('fvec_inner_products_ny',
#   <function faiss._swigfaiss_avx2.fvec_inner_products_ny>),
#  ('fvec_madd', <function faiss._swigfaiss_avx2.fvec_madd>),
#  ('fvec_madd_and_argmin',
#   <function faiss._swigfaiss_avx2.fvec_madd_and_argmin>),
#  ('fvec_norm_L2sqr', <function faiss._swigfaiss_avx2.fvec_norm_L2sqr>),
#  ('fvec_norms_L2', <function faiss._swigfaiss_avx2.fvec_norms_L2>),
#  ('fvec_norms_L2sqr', <function faiss._swigfaiss_avx2.fvec_norms_L2sqr>),
#  ('fvec_renorm_L2', <function faiss._swigfaiss_avx2.fvec_renorm_L2>),
#  ('fvecs2bitvecs', <function faiss._swigfaiss_avx2.fvecs2bitvecs>),
#  ('fvecs_maybe_subsample',
#   <function faiss._swigfaiss_avx2.fvecs_maybe_subsample>),
#  ('get_cycles', <function faiss._swigfaiss_avx2.get_cycles>),
#  ('get_extra_distance_computer',
#   <function faiss._swigfaiss_avx2.get_extra_distance_computer>),
#  ('get_invlist_range', <function faiss._swigfaiss_avx2.get_invlist_range>),
#  ('get_mem_usage_kb', <function faiss._swigfaiss_avx2.get_mem_usage_kb>),
#  ('get_num_gpus', <function faiss._swigfaiss_avx2.get_num_gpus>),
#  ('getmillisecs', <function faiss._swigfaiss_avx2.getmillisecs>),
#  ('gpu_profiler_start', <function faiss._swigfaiss_avx2.gpu_profiler_start>),
#  ('gpu_profiler_stop', <function faiss._swigfaiss_avx2.gpu_profiler_stop>),
#  ('gpu_sync_all_devices',
#   <function faiss._swigfaiss_avx2.gpu_sync_all_devices>),
#  ('hamming_count_thres', <function faiss._swigfaiss_avx2.hamming_count_thres>),
#  ('hamming_range_search',
#   <function faiss._swigfaiss_avx2.hamming_range_search>),
#  ('hammings', <function faiss._swigfaiss_avx2.hammings>),
#  ('hammings_knn', <function faiss._swigfaiss_avx2.hammings_knn>),
#  ('hammings_knn_hc', <function faiss._swigfaiss_avx2.hammings_knn_hc>),
#  ('hammings_knn_mc', <function faiss._swigfaiss_avx2.hammings_knn_mc>),
#  ('handle_AutoTuneCriterion', <function faiss.handle_AutoTuneCriterion>),
#  ('handle_Clustering', <function faiss.handle_Clustering>),
#  ('handle_Index', <function faiss.handle_Index>),
#  ('handle_IndexBinary', <function faiss.handle_IndexBinary>),
#  ('handle_MatrixStats', <function faiss.handle_MatrixStats>),
#  ('handle_ParameterSpace', <function faiss.handle_ParameterSpace>),
#  ('handle_Quantizer', <function faiss.handle_Quantizer>),
#  ('handle_VectorTransform', <function faiss.handle_VectorTransform>),
#  ('hash_bytes', <function faiss._swigfaiss_avx2.hash_bytes>),
#  ('ignore_SIGTTIN', <function faiss._swigfaiss_avx2.ignore_SIGTTIN>),
#  ('imbalance_factor', <function faiss._swigfaiss_avx2.imbalance_factor>),
#  ('index_binary_factory',
#   <function faiss._swigfaiss_avx2.index_binary_factory>),
#  ('index_cpu_to_all_gpus', <function faiss.index_cpu_to_all_gpus>),
#  ('index_cpu_to_gpu',
#   <function faiss.add_ref_in_function.<locals>.replacement_function>),
#  ('index_cpu_to_gpu_multiple',
#   <function faiss._swigfaiss_avx2.index_cpu_to_gpu_multiple>),
#  ('index_cpu_to_gpu_multiple_py',
#   <function faiss.index_cpu_to_gpu_multiple_py>),
#  ('index_cpu_to_gpus_list', <function faiss.index_cpu_to_gpus_list>),
#  ('index_factory', <function faiss._swigfaiss_avx2.index_factory>),
#  ('index_gpu_to_cpu', <function faiss._swigfaiss_avx2.index_gpu_to_cpu>),
#  ('inner_product_to_L2sqr',
#   <function faiss._swigfaiss_avx2.inner_product_to_L2sqr>),
#  ('inspect',
#   <module 'inspect' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/inspect.py'>),
#  ('instr_set', 'AVX2'),
#  ('instruction_set', <function faiss.instruction_set>),
#  ('int64_rand', <function faiss._swigfaiss_avx2.int64_rand>),
#  ('int64_rand_max', <function faiss._swigfaiss_avx2.int64_rand_max>),
#  ('int_maxheap_array_t', faiss.swigfaiss_avx2.int_maxheap_array_t),
#  ('int_maxheap_array_t_swigregister',
#   <function faiss._swigfaiss_avx2.int_maxheap_array_t_swigregister>),
#  ('int_minheap_array_t', faiss.swigfaiss_avx2.int_minheap_array_t),
#  ('int_minheap_array_t_swigregister',
#   <function faiss._swigfaiss_avx2.int_minheap_array_t_swigregister>),
#  ('ivec_checksum', <function faiss._swigfaiss_avx2.ivec_checksum>),
#  ('ivec_hist', <function faiss._swigfaiss_avx2.ivec_hist>),
#  ('kmax', <function faiss.kmax>),
#  ('kmeans_clustering', <function faiss._swigfaiss_avx2.kmeans_clustering>),
#  ('kmin', <function faiss.kmin>),
#  ('knn_L2sqr', <function faiss._swigfaiss_avx2.knn_L2sqr>),
#  ('knn_L2sqr_base_shift',
#   <function faiss._swigfaiss_avx2.knn_L2sqr_base_shift>),
#  ('knn_L2sqr_by_idx', <function faiss._swigfaiss_avx2.knn_L2sqr_by_idx>),
#  ('knn_extra_metrics', <function faiss._swigfaiss_avx2.knn_extra_metrics>),
#  ('knn_inner_product', <function faiss._swigfaiss_avx2.knn_inner_product>),
#  ('knn_inner_products_by_idx',
#   <function faiss._swigfaiss_avx2.knn_inner_products_by_idx>),
#  ('lo_build', <function faiss._swigfaiss_avx2.lo_build>),
#  ('lo_listno', <function faiss._swigfaiss_avx2.lo_listno>),
#  ('lo_offset', <function faiss._swigfaiss_avx2.lo_offset>),
#  ('logger', <Logger faiss (WARNING)>),
#  ('logging',
#   <module 'logging' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/logging/__init__.py'>),
#  ('lrand', <function faiss.randint>),
#  ('match_hamming_thres', <function faiss._swigfaiss_avx2.match_hamming_thres>),
#  ('matrix_qr', <function faiss._swigfaiss_avx2.matrix_qr>),
#  ('memcpy', <function faiss._swigfaiss_avx2.memcpy>),
#  ('merge_into', <function faiss._swigfaiss_avx2.merge_into>),
#  ('merge_result_table_with',
#   <function faiss._swigfaiss_avx2.merge_result_table_with>),
#  ('normalize_L2', <function faiss.normalize_L2>),
#  ('np',
#   <module 'numpy' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/__init__.py'>),
#  ('obj', <function faiss._swigfaiss_avx2.write_index_binary>),
#  ('omp_get_max_threads', <function faiss._swigfaiss_avx2.omp_get_max_threads>),
#  ('omp_set_num_threads', <function faiss._swigfaiss_avx2.omp_set_num_threads>),
#  ('pairwise_L2sqr', <function faiss._swigfaiss_avx2.pairwise_L2sqr>),
#  ('pairwise_distances', <function faiss.pairwise_distances>),
#  ('pairwise_extra_distances',
#   <function faiss._swigfaiss_avx2.pairwise_extra_distances>),
#  ('pairwise_indexed_L2sqr',
#   <function faiss._swigfaiss_avx2.pairwise_indexed_L2sqr>),
#  ('pairwise_indexed_inner_product',
#   <function faiss._swigfaiss_avx2.pairwise_indexed_inner_product>),
#  ('pdb',
#   <module 'pdb' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/pdb.py'>),
#  ('platform',
#   <module 'platform' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/platform.py'>),
#  ('popcount64', <function faiss._swigfaiss_avx2.popcount64>),
#  ('rand', <function faiss.rand>),
#  ('rand_perm', <function faiss._swigfaiss_avx2.rand_perm>),
#  ('randint', <function faiss.randint>),
#  ('randn', <function faiss.randn>),
#  ('range_search_L2sqr', <function faiss._swigfaiss_avx2.range_search_L2sqr>),
#  ('range_search_inner_product',
#   <function faiss._swigfaiss_avx2.range_search_inner_product>),
#  ('ranklist_handle_ties',
#   <function faiss._swigfaiss_avx2.ranklist_handle_ties>),
#  ('ranklist_intersection_size',
#   <function faiss._swigfaiss_avx2.ranklist_intersection_size>),
#  ('read_InvertedLists', <function faiss._swigfaiss_avx2.read_InvertedLists>),
#  ('read_ProductQuantizer',
#   <function faiss._swigfaiss_avx2.read_ProductQuantizer>),
#  ('read_VectorTransform',
#   <function faiss._swigfaiss_avx2.read_VectorTransform>),
#  ('read_index', <function faiss._swigfaiss_avx2.read_index>),
#  ('read_index_binary', <function faiss._swigfaiss_avx2.read_index_binary>),
#  ('real_to_binary', <function faiss._swigfaiss_avx2.real_to_binary>),
#  ('reflection', <function faiss._swigfaiss_avx2.reflection>),
#  ('replace_method', <function faiss.replace_method>),
#  ('replacement_map_add', <function faiss.replacement_map_add>),
#  ('replacement_map_search_multiple',
#   <function faiss.replacement_map_search_multiple>),
#  ('rev_swig_ptr', <function faiss._swigfaiss_avx2.rev_swig_ptr>),
#  ('search_and_return_centroids',
#   <function faiss._swigfaiss_avx2.search_and_return_centroids>),
#  ('search_centroid', <function faiss._swigfaiss_avx2.search_centroid>),
#  ('search_with_parameters',
#   <function faiss._swigfaiss_avx2.search_with_parameters>),
#  ('serialize_index', <function faiss.serialize_index>),
#  ('serialize_index_binary', <function faiss.serialize_index_binary>),
#  ('set_invlist_range', <function faiss._swigfaiss_avx2.set_invlist_range>),
#  ('subprocess',
#   <module 'subprocess' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/subprocess.py'>),
#  ('swig_ptr', <function faiss._swigfaiss_avx2.swig_ptr>),
#  ('swigfaiss_avx2',
#   <module 'faiss.swigfaiss_avx2' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/swigfaiss_avx2.py'>),
#  ('symbol', 'write_index_binary'),
#  ('sys', <module 'sys' (built-in)>),
#  ('the_class', faiss.swigfaiss_avx2.int_minheap_array_t),
#  ('this_module',
#   <module 'faiss' from '/home/wejiang/anaconda3/envs/py37/lib/python3.7/site-packages/faiss/__init__.py'>),
#  ('try_extract_index_ivf',
#   <function faiss._swigfaiss_avx2.try_extract_index_ivf>),
#  ('vector_float_to_array', <function faiss.vector_float_to_array>),
#  ('vector_name_map',
#   {'Float': 'float32',
#    'Byte': 'uint8',
#    'Char': 'int8',
#    'Uint64': 'uint64',
#    'Long': 'int64',
#    'Int': 'int32',
#    'Double': 'float64'}),
#  ('vector_to_array', <function faiss.vector_to_array>),
#  ('wait', <function faiss._swigfaiss_avx2.wait>),
#  ('write_InvertedLists', <function faiss._swigfaiss_avx2.write_InvertedLists>),
#  ('write_ProductQuantizer',
#   <function faiss._swigfaiss_avx2.write_ProductQuantizer>),
#  ('write_VectorTransform',
#   <function faiss._swigfaiss_avx2.write_VectorTransform>),
#  ('write_index', <function faiss._swigfaiss_avx2.write_index>),
#  ('write_index_binary', <function faiss._swigfaiss_avx2.write_index_binary>)]
